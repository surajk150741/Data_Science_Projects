# %%
import pandas as pd

# %%
df = pd.read_csv('Desktop/pandas_data_survey/survey_results_public.csv', index_col = "Respondent")
schema_df = pd.read_csv('Desktop/pandas_data_survey/survey_results_schema.csv', index_col = "Column")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-41157631bebc> in <module>
# ----> 1 df = pd.read_csv('Desktop/pandas_data_survey/survey_results_public.csv', index_col = "Respondent")
#       2 schema_df = pd.read_csv('Desktop/pandas_data_survey/survey_results_schema.csv', index_col = "Column")
#
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(14)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %% [markdown]
# - Now lets convert the column name "convertedcomp" for sallery to usdollars

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace = True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %% [markdown]
# Let's convert the above hobbyist results to True and False boolian values(we can use map method for the same)

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# If there were some more things(other than 'Yes' or 'No') and we want to change only yes or no, then we can use "replace method "
# Out:
# Respondent
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 64858    NaN
# 64867    NaN
# 64898    NaN
# 64925    NaN
# 65112    NaN
# Name: Hobbyist, Length: 64461, dtype: object

# %%
#Now I don't believe we have an inplace argument above for map, so we can do as following
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN     True   NaN
# 64867                                                     NaN     True   NaN
# 64898                                                     NaN     True   NaN
# 64925                                                     NaN     True   NaN
# 65112                                                     NaN     True   NaN
#
# ...
